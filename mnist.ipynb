# %%
import tensorflow as tf 
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
#normalization 
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
import matplotlib.pyplot as plt
# plt.imshow(x_train[0], cmap=plt.cm.binary)

print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
print(len(mnist.load_data()[0]))
# Out:
# 2

# %%
#creating model

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))

model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
model.fit(x_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.3077 - accuracy: 0.9157
# Epoch 2/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1410 - accuracy: 0.9583
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0970 - accuracy: 0.9711
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0732 - accuracy: 0.9780
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0568 - accuracy: 0.9829

# %%
model.save("myNumReader")
# Out:
# INFO:tensorflow:Assets written to: myNumReader\assets
# INFO:tensorflow:Assets written to: myNumReader\assets

# %%
new_model = tf.keras.models.load_model("myNumReader")
import matplotlib.pyplot as pt 
import os as operating_syste
pt.imshow()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Python\python_learning\neural network\CNN_with_tensorflow\mnist.ipynb Cell 7 line 4
#       <a href='vscode-notebook-cell:/d%3A/Python/python_learning/neural%20network/CNN_with_tensorflow/mnist.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as pt
#       <a href='vscode-notebook-cell:/d%3A/Python/python_learning/neural%20network/CNN_with_tensorflow/mnist.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> import os as operating_syste
# ----> <a href='vscode-notebook-cell:/d%3A/Python/python_learning/neural%20network/CNN_with_tensorflow/mnist.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> pt.imshow()
#
# TypeError: imshow() missing 1 required positional argument: 'X'

# %%
predictions = new_model.predict([x_test])
# Out:
# 313/313 [==============================] - 1s 1ms/step

# %%
print(predictions.shape)
# Out:
# (10000, 10)

# %%
import numpy as np
print(np.argmax(predictions[0]))
# Out:
# 7

# %%
plt.imshow(x_test[0])

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
path = "D:\\Python\\python_learning\\neural network\\cats-dogs-dataset\\training_set\\cats"

import os

# %%
print(os.listdir(path))
# Out:
# ['cat.1.jpg', 'cat.10.jpg', 'cat.100.jpg', 'cat.1000.jpg', 'cat.1001.jpg', 'cat.1002.jpg', 'cat.1003.jpg', 'cat.1004.jpg', 'cat.1005.jpg', 'cat.1006.jpg', 'cat.1007.jpg', 'cat.1008.jpg', 'cat.1009.jpg', 'cat.101.jpg', 'cat.1010.jpg', 'cat.1011.jpg', 'cat.1012.jpg', 'cat.1013.jpg', 'cat.1014.jpg', 'cat.1015.jpg', 'cat.1016.jpg', 'cat.1017.jpg', 'cat.1018.jpg', 'cat.1019.jpg', 'cat.102.jpg', 'cat.1020.jpg', 'cat.1021.jpg', 'cat.1022.jpg', 'cat.1023.jpg', 'cat.1024.jpg', 'cat.1025.jpg', 'cat.1026.jpg', 'cat.1027.jpg', 'cat.1028.jpg', 'cat.1029.jpg', 'cat.103.jpg', 'cat.1030.jpg', 'cat.1031.jpg', 'cat.1032.jpg', 'cat.1033.jpg', 'cat.1034.jpg', 'cat.1035.jpg', 'cat.1036.jpg', 'cat.1037.jpg', 'cat.1038.jpg', 'cat.1039.jpg', 'cat.104.jpg', 'cat.1040.jpg', 'cat.1041.jpg', 'cat.1042.jpg', 'cat.1043.jpg', 'cat.1044.jpg', 'cat.1045.jpg', 'cat.1046.jpg', 'cat.1047.jpg', 'cat.1048.jpg', 'cat.1049.jpg', 'cat.105.jpg', 'cat.1050.jpg', 'cat.1051.jpg', 'cat.1052.jpg', 'cat.1053.jpg', 'cat.1054.jpg', 
# ...

# %%
import re
def extract_number(filename):
    match = re.search(r'\d+', filename)
    if match:
        return int(match.group())
    return -1  # Return a default value if no number is found

# List all files in the directory
directory = '/path/to/your/directory'
files = os.listdir(directory)

# Sort the files using the custom sorting function
sorted_files = sorted(files, key=extract_number)

# Print the sorted file names
for filename in sorted_files:
    print(filename)
